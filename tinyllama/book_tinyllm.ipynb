# %%
import os,sys
root_folder = '/home/sudarshan/notebooks'
for dirpath, _, _ in os.walk(root_folder):
    sys.path.append(dirpath)

# %%
from tinyllm import ask_tinyllama

ask_tinyllama("How I can train you?")
# Out:
# === Prompt ===
# How I can train you?
#
# === Response ===
# How I can train you?
#
# Cameron: (smiling) I don't know, but I'm sure you'll be able to do it.
#
# Tom: (laughing) We'll see.
#
# Scene 5:
