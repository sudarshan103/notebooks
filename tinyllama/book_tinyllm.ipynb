# %%
import os,sys
root_folder = '/home/sudarshan/notebooks'
for dirpath, _, _ in os.walk(root_folder):
    sys.path.append(dirpath)

# %%
from tinyllm import ask_tinyllama

ask_tinyllama("Tell me about yourself")
# Out:
# Error importing huggingface_hub.hf_api: cannot import name 'JSONDecodeError' from 'simplejson' (unknown location)
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from tinyllm import ask_tinyllama
#       3 ask_tinyllama("Tell me about yourself")
#
# File ~/notebooks/tinyllama/tinyllm.py:1
# ----> 1 from transformers import AutoModelForCausalLM, AutoTokenizer
#       2 import torch
#       4 # Choose the model: TinyLlama's 1.1B chat version
#
# File ~/notebooks/.venv/lib/python3.12/site-packages/transformers/__init__.py:27
#      24 from typing import TYPE_CHECKING
#      26 # Check the dependencies satisfy the minimal versions required.
# ---> 27 from . import dependency_versions_check
#      28 from .utils import (
#      29     OptionalDependencyNotAvailable,
#      30     _LazyModule,
#    (...)
#      49     logging,
#      50 )
# ...
