# %%
import os,sys
root_folder = '/home/sudarshan/notebooks'
for dirpath, _, _ in os.walk(root_folder):
    sys.path.append(dirpath)

# %%
from tinyllm import ask_tinyllama

ask_tinyllama("Whats Tinyllama?")
# Out:
# === Response ===
# Whats Tinyllama?
# - What do I do if I forget my login details?
#
# After these steps, users can log in to their account using their email and password. The application should have a user-friendly interface with clear instructions on how to navigate the platform. Additionally, it should have a feature that allows users to save their favorite recipes for later.
